# %% [markdown]
# ## Exercise 6 - XML

# %% [markdown]
# 1 Add the necessary libraries (xml and pandas).

# %%
import xml.etree.ElementTree as e
import pandas as pd

# %% [markdown]
# 2 Save the XML structure shown below as a string in a variable. In addition, load the content from the file *users_first.xml* into another variable.

# %%
# <?xml version='1.0' encoding='UTF-8'?><records><record type='customer'><name>Lawrence Burke</name><phone>(815) 571-8746</phone><email>vulputate.lacus@elitfermentum.net</email><address><streetaddress>P.O. Box 478, 5254 Mi St.</streetaddress><country>Mexico</country><postalZip>22044</postalZip></address></record><record type='employee'><name>Angela Hinton</name><phone>(997) 412-6965</phone><email>elit.dictum@egestas.net</email><address><streetaddress>696-4409 Nunc Rd.</streetaddress><country>Germany</country><postalZip>661217</postalZip></address></record><record type='customer'><name>Whitney Flowers</name><phone>1-573-471-9738</phone><email>consectetuer.adipiscing.elit@ridiculusmus.ca</email><address><streetaddress>6978 Et, Av.</streetaddress><country>Indonesia</country><postalZip>28164</postalZip></address></record><record type='customer'><name>Darius Burt</name><phone>1-675-212-4934</phone><email>sociis.natoque@ut.org</email><address><streetaddress>7705 Ut Street</streetaddress><country>Indonesia</country><postalZip>94783-300</postalZip></address></record><record type='customer'><name>Solomon Blair</name><phone></phone><email>pede.suspendisse.dui@commodoat.edu</email><address><streetaddress>Ap #877-8946 Sociosqu Street</streetaddress><country>Germany</country><postalZip>113513</postalZip></address></record></records>

# %%
xml_string = """<?xml version='1.0' encoding='UTF-8'?><records><record type='customer'><name>Lawrence Burke</name><phone>(815) 571-8746</phone><email>vulputate.lacus@elitfermentum.net</email><address><streetaddress>P.O. Box 478, 5254 Mi St.</streetaddress><country>Mexico</country><postalZip>22044</postalZip></address></record><record type='employee'><name>Angela Hinton</name><phone>(997) 412-6965</phone><email>elit.dictum@egestas.net</email><address><streetaddress>696-4409 Nunc Rd.</streetaddress><country>Germany</country><postalZip>661217</postalZip></address></record><record type='customer'><name>Whitney Flowers</name><phone>1-573-471-9738</phone><email>consectetuer.adipiscing.elit@ridiculusmus.ca</email><address><streetaddress>6978 Et, Av.</streetaddress><country>Indonesia</country><postalZip>28164</postalZip></address></record><record type='customer'><name>Darius Burt</name><phone>1-675-212-4934</phone><email>sociis.natoque@ut.org</email><address><streetaddress>7705 Ut Street</streetaddress><country>Indonesia</country><postalZip>94783-300</postalZip></address></record><record type='customer'><name>Solomon Blair</name><phone></phone><email>pede.suspendisse.dui@commodoat.edu</email><address><streetaddress>Ap #877-8946 Sociosqu Street</streetaddress><country>Germany</country><postalZip>113513</postalZip></address></record></records>"""

with open('users_first.xml', 'r') as file:
    xml_content = file.read()

# %% [markdown]
# 3 From the contents of both variables, form lists C1 and C2, in which the contents of the XML data are stored as dictionary-type objects. **NOTE**: the attributes presented at the record level must be included in the objects and the identifiers under the address identifier must be brought to a higher level next to user's other properties!
#
# Below is a model showing the structure of the first object:
#
# <pre>[{
#     'type': 'customer',
#     'name': 'Morgan Sykes',
#     'phone': '1-183-546-6564',
#     'email': 'lorem.auctor@vulputatemauris.net',
#     'streetaddress' : '2594 Tellus St.',
#     'country': 'Russian Federation',
#     'postalZip': '584585'
# }]<pre>

# %%
def parse_xml_to_dict(xml_data):
    root = e.fromstring(xml_data)
    records = []
    for record in root.findall('record'):
        record_dict = record.attrib
        for child in record:
            if child.tag == 'address':
                for addr_child in child:
                    record_dict[addr_child.tag] = addr_child.text
            else:
                record_dict[child.tag] = child.text
        records.append(record_dict)
    return records

C1 = parse_xml_to_dict(xml_string)
C2 = parse_xml_to_dict(xml_content)

# %% [markdown]
# 4 Convert both lists into dataframes and finally combine them into one dataframe (remember to reset the index of the new dataframe!). Print the content of the generated dataframe.

# %%
df_C1 = pd.DataFrame(C1)
df_C2 = pd.DataFrame(C2)
combined_df = pd.concat([df_C1, df_C2]).reset_index(drop=True)
print(combined_df)
# Out:
#         type               name           phone  \
# 0   customer     Lawrence Burke  (815) 571-8746
# 1   employee      Angela Hinton  (997) 412-6965
# 2   customer    Whitney Flowers  1-573-471-9738
# 3   customer        Darius Burt  1-675-212-4934
# 4   customer      Solomon Blair            None
# 5   customer       Morgan Sykes  1-183-546-6564
# 6   employee       Zia Stafford  (621) 483-5714
# 7   employee     Cooper Ramirez  (716) 895-3353
# 8   customer  Richard Armstrong  (450) 317-2624
# 9   employee     Flavia Delaney            None
# 10  customer  Branden Henderson  1-314-584-1088
# 11  employee    Hector Kirkland  (325) 535-9750
# 12  customer        Luke Hooper            None
# 13  employee      Moses Dejesus  1-337-767-2455
# 14  customer          Finn Pena  1-746-189-1226
# 15  employee    Lester Espinoza  1-378-721-6318
# 16  employee     Nelle Stafford  1-246-844-4648
# 17  customer        Amber Casey            None
# 18  customer      Jordan Strong  1-188-391-2011
# 19  employee    Elton Mcpherson  1-733-172-5377
#
#                                            email  \
# 0              vulputate.lacus@elitfermentum.net
# 1                        elit.dictum@egestas.net
# 2   consectetuer.adipiscing.elit@ridiculusmus.ca
# 3                          sociis.natoque@ut.org
# 4             pede.suspendisse.dui@commodoat.edu
# 5               lorem.auctor@vulputatemauris.net
# 6                  ornare.fusce@felisdonec.co.uk
# 7     suspendisse@consectetueradipiscingelit.edu
# 8                        lacinia.mattis@urna.org
# 9                    rutrum.lorem.ac@inmagna.org
# 10                   iaculis@felisnullatempor.ca
# 11                            elit@orcilacus.org
# 12                 vitae.sodales@vitaesodales.ca
# 13                       pede@donecdignissim.org
# 14                           et.euismod.et@ac.ca
# 15                       vel.nisl.quisque@ad.org
# 16                            ligula@posuere.com
# 17                          diam@nequeetnunc.com
# 18                   tincidunt@quamcurabitur.net
# 19                       praesent@tempuseu.co.uk
#
#                         streetaddress             country    postalZip
# 0           P.O. Box 478, 5254 Mi St.              Mexico        22044
# 1                   696-4409 Nunc Rd.             Germany       661217
# 2                        6978 Et, Av.           Indonesia        28164
# 3                      7705 Ut Street           Indonesia    94783-300
# 4        Ap #877-8946 Sociosqu Street             Germany       113513
# 5                     2594 Tellus St.  Russian Federation       584585
# 6               Ap #419-5905 Nibh Rd.         Netherlands         7308
# 7                 667-4582 Mollis Ave               India        43714
# 8                Ap #120-495 Ut, Road  Russian Federation        53415
# 9                    870-3073 Et, Av.             Austria        03247
# 10  P.O. Box 961, 9477 Gravida Avenue            Pakistan        50217
# 11             541-4061 Ultricies Ave      United Kingdom         3865
# 12          Ap #385-5179 Luctus, Road             Germany         3660
# 13         Ap #639-9807 Phasellus St.             Germany       903866
# 14              Ap #668-4837 Nec Road         Netherlands        32910
# 15                     4395 Elit, St.               Chile  07740-64584
# 16          Ap #640-4104 Maecenas St.               Chile       800308
# 17             Ap #944-5570 Nunc. Rd.            Pakistan       154758
# 18            Ap #426-2862 Lectus Rd.       United States     37144455
# 19               110-7294 Tempus Road             Belgium        89525

# %% [markdown]
# 5 Some users are missing a phone number. Print the number of these users.

# %%
missing_phone_count = combined_df['phone'].isna().sum()
print("\nNumber of users missing a phone number:", missing_phone_count)
# Out:
# Number of users missing a phone number: 4
